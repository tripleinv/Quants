# %% [markdown]
# # Adding Removed S&P 500 Tickers

# %% [markdown]
# ## Overview:
#
# This step aims to add historically removed S&P500 company tickers to eliminate the survivorship biase among the financial data.

# %%
# import libraries
import yfinance as yf
import pandas as pd
import requests
import json
import numpy as np
import pickle
import copy
import datetime as dt
import os

headers = {"User-Agent": "ian.ye.fu@gmail.com"} 
data_folder_download = './datasets/download/'
data_folder_generate = './datasets/generate/'

# %% [markdown]
# ## Step 1: Get removed and added tickers

# %%
recent_changes_tickers = pd.read_csv(data_folder_download + 'sp500_recent_changes.csv', header = 0, index_col = 'Date')

# %%
recent_changes_tickers.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 349 entries, Date to June 17, 1997
# Data columns (total 5 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Added      336 non-null    object
#  1   Added.1    336 non-null    object
#  2   Removed    330 non-null    object
#  3   Removed.1  330 non-null    object
#  4   Reason     349 non-null    object
# dtypes: object(5)
# memory usage: 16.4+ KB

# %%
# Check the overlap between tickers added and tickers removed
set_added_tickers = set(recent_changes_tickers["Added"].tolist())
set_removed_tickers = set(recent_changes_tickers["Removed"].tolist())
print(f'number of ticker overlaps between removed tickers and added tickers: {len(list(set_added_tickers.intersection(set_removed_tickers)))}')
# Out:
# number of ticker overlaps between removed tickers and added tickers: 109

# %%
# create added_tickers_df
added_tickers_df = recent_changes_tickers.iloc[1: ][['Added', 'Added.1']].dropna(axis = 0)
added_tickers_df.index = pd.to_datetime(added_tickers_df.index, format='%B %d, %Y')
added_tickers_df = added_tickers_df.reset_index().rename(columns = {'Date':'Date_Added', 'Added': 'Added_Ticker', 'Added.1': 'Security_Added'}).set_index('Added_Ticker')

# %%
#Only get the tickers added after 2013 for the analysis period between 2013 to 2024.
added_tickers_df = added_tickers_df.query('Date_Added >= "2013"')
with open(data_folder_generate + 'added_tickers_df.pkl', 'wb') as f: 
    pickle.dump(added_tickers_df, f)

# %%
with open(data_folder_generate + 'added_tickers_df.pkl', 'rb') as f: 
    added_tickers_df = pickle.load(f)

# %%
added_tickers_df.head()
# Out:
#              Date_Added Security_Added
# Added_Ticker
# KKR          2024-06-24            KKR
# CRWD         2024-06-24    CrowdStrike
# GDDY         2024-06-24        GoDaddy
# VST          2024-05-08         Vistra
# GEV          2024-04-02     GE Vernova

# %%
# create removed_tickers_df
removed_tickers_df = recent_changes_tickers.iloc[1: ][['Removed', 'Removed.1']].dropna(axis = 0)
removed_tickers_df.index = pd.to_datetime(removed_tickers_df.index, format='%B %d, %Y')
removed_tickers_df = removed_tickers_df.reset_index().rename(columns = {'Date':'Date_Removed', 'Removed': 'Removed_Ticker', 'Removed.1': 'Security_Removed'}).set_index('Removed_Ticker')

# %%
removed_tickers_df = removed_tickers_df.query('Date_Removed >= "2013"')
with open(data_folder_generate + 'removed_tickers_df.pkl', 'wb') as f: 
    pickle.dump(removed_tickers_df, f)

# %%
with open(data_folder_generate + 'removed_tickers_df.pkl', 'rb') as f: 
    removed_tickers_df = pickle.load(f)

# %%
removed_tickers_df.head()
# Out:
#                Date_Removed           Security_Removed
# Removed_Ticker
# RHI              2024-06-24                Robert Half
# CMA              2024-06-24                   Comerica
# ILMN             2024-06-24             Illumina, Inc.
# PXD              2024-05-08  Pioneer Natural Resources
# XRAY             2024-04-03            Dentsply Sirona

# %% [markdown]
# ## Step 2: Get the CIK numbers for removed tickers

# %%
def cik_matching_ticker(ticker, headers=headers):
    """
    get the cik number for tickers
    """
    ticker = ticker.upper().replace(".", "-")
    ticker_json = requests.get(
        "https://www.sec.gov/files/company_tickers.json", headers=headers
    ).json()

    for company in ticker_json.values():
        if company["ticker"] == ticker:
            cik = str(company["cik_str"]).zfill(10)
            return cik
    raise ValueError(f"Ticker {ticker} not found in SEC database")

# %%
removed_tickers_list = removed_tickers_df.index.tolist()

# %%
for ticker in removed_tickers_list:
    try:
        print(f"Fetching CIK for {ticker}")  
        removed_tickers_df.loc[ticker, 'CIK'] = cik_matching_ticker(ticker, headers)
    except ValueError as e:
        print(f"Error for ticker {ticker}: {e}")
        continue
# Out:
# Fetching CIK for RHI
# Fetching CIK for CMA
# Fetching CIK for ILMN
# Fetching CIK for PXD
# Error for ticker PXD: Ticker PXD not found in SEC database
# Fetching CIK for XRAY
# Fetching CIK for VFC
# Fetching CIK for WHR
# Fetching CIK for ZION
# Fetching CIK for SEE
# Fetching CIK for ALK
# Fetching CIK for SEDG
# Fetching CIK for OGN
# Fetching CIK for ATVI
# Error for ticker ATVI: Ticker ATVI not found in SEC database
# Fetching CIK for DXC
# Fetching CIK for LNC
# Fetching CIK for NWL
# Fetching CIK for AAP
# Fetching CIK for DISH
# Error for ticker DISH: Ticker DISH not found in SEC database
# Fetching CIK for FRC
# Error for ticker FRC: Ticker FRC not found in SEC database
# Fetching CIK for LUMN
# Fetching CIK for SBNY
# Error for ticker SBNY: Ticker SBNY not found in SEC database
# Fetching CIK for SIVB
# Error for ticker SIVB: Ticker SIVB not found in SEC database
# Fetching CIK for VNO
# Fetching CIK for ABMD
# Error for ticker ABMD: Ticker ABMD not found in SEC database
# Fetching CIK for FBHS
# Error for ticker FBHS: Ticker FBHS not found in SEC database
# Fetching CIK for MBC
# Fetching CIK for TWTR
# Error for ticker TWTR: Ticker TWTR not found in SEC database
# Fetching CIK for NLSN
# Error for ticker NLSN: Ticker NLSN not found in SEC database
# Fetching CIK for CTXS
# Error for ticker CTXS: Ticker CTXS not found in SEC database
# Fetching CIK for DRE
# Error for ticker DRE: Ticker DRE not found in SEC database
# Fetching CIK for PVH
# Fetching CIK for PENN
# Fetching CIK for UA
# Fetching CIK for UAA
# Fetching CIK for IPGP
# Fetching CIK for CERN
# Error for ticker CERN: Ticker CERN not found in SEC database
# Fetching CIK for PBCT
# Error for ticker PBCT: Ticker PBCT not found in SEC database
# Fetching CIK for INFO
# Error for ticker INFO: Ticker INFO not found in SEC database
# Fetching CIK for XLNX
# Error for ticker XLNX: Ticker XLNX not found in SEC database
# Fetching CIK for GPS
# Fetching CIK for LEG
# Fetching CIK for HBI
# Fetching CIK for WU
# Fetching CIK for KSU
# Error for ticker KSU: Ticker KSU not found in SEC database
# Fetching CIK for PRGO
# Fetching CIK for UNM
# Fetching CIK for NOV
# Fetching CIK for MXIM
# Error for ticker MXIM: Ticker MXIM not found in SEC database
# Fetching CIK for ALXN
# Error for ticker ALXN: Ticker ALXN not found in SEC database
# Fetching CIK for HFC
# Error for ticker HFC: Ticker HFC not found in SEC database
# Fetching CIK for FLIR
# Error for ticker FLIR: Ticker FLIR not found in SEC database
# Fetching CIK for VAR
# Error for ticker VAR: Ticker VAR not found in SEC database
# Fetching CIK for FLS
# Fetching CIK for SLG
# Fetching CIK for XRX
# Fetching CIK for VNT
# Fetching CIK for FTI
# Fetching CIK for CXO
# Error for ticker CXO: Ticker CXO not found in SEC database
# Fetching CIK for TIF
# Error for ticker TIF: Ticker TIF not found in SEC database
# Fetching CIK for AIV
# Fetching CIK for NBL
# Error for ticker NBL: Ticker NBL not found in SEC database
# Fetching CIK for ETFC
# Error for ticker ETFC: Ticker ETFC not found in SEC database
# Fetching CIK for HRB
# Fetching CIK for COTY
# Fetching CIK for KSS
# Fetching CIK for ADS
# Error for ticker ADS: Ticker ADS not found in SEC database
# Fetching CIK for HOG
# Fetching CIK for JWN
# Fetching CIK for HP
# Fetching CIK for CPRI
# Fetching CIK for AGN
# Error for ticker AGN: Ticker AGN not found in SEC database
# Fetching CIK for M
# Fetching CIK for RTN
# Error for ticker RTN: Ticker RTN not found in SEC database
# Fetching CIK for ARNC
# Error for ticker ARNC: Ticker ARNC not found in SEC database
# Fetching CIK for XEC
# Error for ticker XEC: Ticker XEC not found in SEC database
# Fetching CIK for WCG
# Error for ticker WCG: Ticker WCG not found in SEC database
# Fetching CIK for AMG
# Fetching CIK for TRIP
# Fetching CIK for MAC
# Fetching CIK for STI
# Fetching CIK for VIAB
# Error for ticker VIAB: Ticker VIAB not found in SEC database
# Fetching CIK for CELG
# Error for ticker CELG: Ticker CELG not found in SEC database
# Fetching CIK for NKTR
# Fetching CIK for JEF
# Fetching CIK for TSS
# Error for ticker TSS: Ticker TSS not found in SEC database
# Fetching CIK for APC
# Error for ticker APC: Ticker APC not found in SEC database
# Fetching CIK for FL
# Fetching CIK for RHT
# Error for ticker RHT: Ticker RHT not found in SEC database
# Fetching CIK for LLL
# Error for ticker LLL: Ticker LLL not found in SEC database
# Fetching CIK for BMS
# Error for ticker BMS: Ticker BMS not found in SEC database
# Fetching CIK for MAT
# Fetching CIK for DWDP
# Error for ticker DWDP: Ticker DWDP not found in SEC database
# Fetching CIK for FLR
# Fetching CIK for BHF
# Fetching CIK for GT
# Fetching CIK for NFX
# Error for ticker NFX: Ticker NFX not found in SEC database
# Fetching CIK for PCG
# Fetching CIK for SCG
# Error for ticker SCG: Ticker SCG not found in SEC database
# Fetching CIK for ESRX
# Error for ticker ESRX: Ticker ESRX not found in SEC database
# Fetching CIK for COL
# Error for ticker COL: Ticker COL not found in SEC database
# Fetching CIK for AET
# Error for ticker AET: Ticker AET not found in SEC database
# Fetching CIK for SRCL
# Fetching CIK for EQT
# Fetching CIK for CA
# Error for ticker CA: Ticker CA not found in SEC database
# Fetching CIK for EVHC
# Error for ticker EVHC: Ticker EVHC not found in SEC database
# Fetching CIK for ANDV
# Error for ticker ANDV: Ticker ANDV not found in SEC database
# Fetching CIK for XL
# Error for ticker XL: Ticker XL not found in SEC database
# Fetching CIK for GGP
# Error for ticker GGP: Ticker GGP not found in SEC database
# Fetching CIK for DPS
# Error for ticker DPS: Ticker DPS not found in SEC database
# Fetching CIK for TWX
# Error for ticker TWX: Ticker TWX not found in SEC database
# Fetching CIK for RRC
# Fetching CIK for AYI
# Fetching CIK for MON
# Error for ticker MON: Ticker MON not found in SEC database
# Fetching CIK for NAVI
# Fetching CIK for WYN
# Error for ticker WYN: Ticker WYN not found in SEC database
# Fetching CIK for CSRA
# Error for ticker CSRA: Ticker CSRA not found in SEC database
# Fetching CIK for SIG
# Fetching CIK for PDCO
# Fetching CIK for CHK
# Fetching CIK for SNI
# Error for ticker SNI: Ticker SNI not found in SEC database
# Fetching CIK for BCR
# Error for ticker BCR: Ticker BCR not found in SEC database
# Fetching CIK for LVLT
# Error for ticker LVLT: Ticker LVLT not found in SEC database
# Fetching CIK for SPLS
# Error for ticker SPLS: Ticker SPLS not found in SEC database
# Fetching CIK for DOW
# Fetching CIK for DD
# Fetching CIK for WFM
# Error for ticker WFM: Ticker WFM not found in SEC database
# Fetching CIK for AN
# Fetching CIK for RIG
# Fetching CIK for BBBY
# Error for ticker BBBY: Ticker BBBY not found in SEC database
# Fetching CIK for MUR
# Fetching CIK for MNK
# Error for ticker MNK: Ticker MNK not found in SEC database
# Fetching CIK for RAI
# Error for ticker RAI: Ticker RAI not found in SEC database
# Fetching CIK for YHOO
# Error for ticker YHOO: Ticker YHOO not found in SEC database
# Fetching CIK for TDC
# Fetching CIK for R
# Fetching CIK for MJN
# Error for ticker MJN: Ticker MJN not found in SEC database
# Fetching CIK for TGNA
# Fetching CIK for DNB
# Fetching CIK for SWN
# Fetching CIK for URBN
# Fetching CIK for FTR
# Error for ticker FTR: Ticker FTR not found in SEC database
# Fetching CIK for FSLR
# Fetching CIK for HAR
# Error for ticker HAR: Ticker HAR not found in SEC database
# Fetching CIK for LLTC
# Error for ticker LLTC: Ticker LLTC not found in SEC database
# Fetching CIK for ENDP
# Error for ticker ENDP: Ticker ENDP not found in SEC database
# Fetching CIK for PBI
# Fetching CIK for SE
# Fetching CIK for STJ
# Error for ticker STJ: Ticker STJ not found in SEC database
# Fetching CIK for OI
# Fetching CIK for LM
# Error for ticker LM: Ticker LM not found in SEC database
# Fetching CIK for AA
# Fetching CIK for DO
# Fetching CIK for HOT
# Error for ticker HOT: Ticker HOT not found in SEC database
# Fetching CIK for EMC
# Error for ticker EMC: Ticker EMC not found in SEC database
# Fetching CIK for TYC
# Error for ticker TYC: Ticker TYC not found in SEC database
# Fetching CIK for CPGX
# Error for ticker CPGX: Ticker CPGX not found in SEC database
# Fetching CIK for GAS
# Error for ticker GAS: Ticker GAS not found in SEC database
# Fetching CIK for TE
# Error for ticker TE: Ticker TE not found in SEC database
# Fetching CIK for CVC
# Error for ticker CVC: Ticker CVC not found in SEC database
# Fetching CIK for BXLT
# Error for ticker BXLT: Ticker BXLT not found in SEC database
# Fetching CIK for CCE
# Error for ticker CCE: Ticker CCE not found in SEC database
# Fetching CIK for ARG
# Error for ticker ARG: Ticker ARG not found in SEC database
# Fetching CIK for TWC
# Error for ticker TWC: Ticker TWC not found in SEC database
# Fetching CIK for SNDK
# Error for ticker SNDK: Ticker SNDK not found in SEC database
# Fetching CIK for ADT
# Fetching CIK for GME
# Fetching CIK for THC
# Fetching CIK for CAM
# Error for ticker CAM: Ticker CAM not found in SEC database
# Fetching CIK for POM
# Error for ticker POM: Ticker POM not found in SEC database
# Fetching CIK for ESV
# Error for ticker ESV: Ticker ESV not found in SEC database
# Fetching CIK for GMCR
# Error for ticker GMCR: Ticker GMCR not found in SEC database
# Fetching CIK for CNX
# Fetching CIK for PCL
# Error for ticker PCL: Ticker PCL not found in SEC database
# Fetching CIK for PCP
# Error for ticker PCP: Ticker PCP not found in SEC database
# Fetching CIK for BRCM
# Error for ticker BRCM: Ticker BRCM not found in SEC database
# Fetching CIK for ACE
# Error for ticker ACE: Ticker ACE not found in SEC database
# Fetching CIK for FOSL
# Fetching CIK for ALTR
# Fetching CIK for CMCSK
# Error for ticker CMCSK: Ticker CMCSK not found in SEC database
# Fetching CIK for CSC
# Error for ticker CSC: Ticker CSC not found in SEC database
# Fetching CIK for SIAL
# Error for ticker SIAL: Ticker SIAL not found in SEC database
# Fetching CIK for GNW
# Fetching CIK for HCBK
# Error for ticker HCBK: Ticker HCBK not found in SEC database
# Fetching CIK for JOY
# Error for ticker JOY: Ticker JOY not found in SEC database
# Fetching CIK for HSP
# Error for ticker HSP: Ticker HSP not found in SEC database
# Fetching CIK for PLL
# Fetching CIK for DTV
# Error for ticker DTV: Ticker DTV not found in SEC database
# Fetching CIK for NE
# Fetching CIK for FDO
# Error for ticker FDO: Ticker FDO not found in SEC database
# Fetching CIK for KRFT
# Error for ticker KRFT: Ticker KRFT not found in SEC database
# Fetching CIK for ATI
# Fetching CIK for TEG
# Error for ticker TEG: Ticker TEG not found in SEC database
# Fetching CIK for QEP
# Error for ticker QEP: Ticker QEP not found in SEC database
# Fetching CIK for LO
# Error for ticker LO: Ticker LO not found in SEC database
# Fetching CIK for WIN
# Error for ticker WIN: Ticker WIN not found in SEC database
# Fetching CIK for AGN
# Error for ticker AGN: Ticker AGN not found in SEC database
# Fetching CIK for DNR
# Error for ticker DNR: Ticker DNR not found in SEC database
# Fetching CIK for NBR
# Fetching CIK for AVP
# Error for ticker AVP: Ticker AVP not found in SEC database
# Fetching CIK for CFN
# Error for ticker CFN: Ticker CFN not found in SEC database
# Fetching CIK for PETM
# Error for ticker PETM: Ticker PETM not found in SEC database
# Fetching CIK for SWY
# Error for ticker SWY: Ticker SWY not found in SEC database
# Fetching CIK for COV
# Error for ticker COV: Ticker COV not found in SEC database
# Fetching CIK for BMS
# Error for ticker BMS: Ticker BMS not found in SEC database
# Fetching CIK for JBL
# Fetching CIK for BTU
# Fetching CIK for GHC
# Fetching CIK for RDC
# Error for ticker RDC: Ticker RDC not found in SEC database
# Fetching CIK for X
# Fetching CIK for FRX
# Error for ticker FRX: Ticker FRX not found in SEC database
# Fetching CIK for IGT
# Fetching CIK for LSI
# Error for ticker LSI: Ticker LSI not found in SEC database
# Fetching CIK for BEAM
# Fetching CIK for SLM
# Fetching CIK for CLF
# Fetching CIK for WPX
# Error for ticker WPX: Ticker WPX not found in SEC database
# Fetching CIK for LIFE
# Error for ticker LIFE: Ticker LIFE not found in SEC database
# Fetching CIK for ANF
# Fetching CIK for JDSU
# Error for ticker JDSU: Ticker JDSU not found in SEC database
# Fetching CIK for TER
# Fetching CIK for MOLX
# Error for ticker MOLX: Ticker MOLX not found in SEC database
# Fetching CIK for JCP
# Error for ticker JCP: Ticker JCP not found in SEC database
# Fetching CIK for NYX
# Error for ticker NYX: Ticker NYX not found in SEC database
# Fetching CIK for DELL
# Fetching CIK for AMD
# Fetching CIK for SAI
# Fetching CIK for BMC
# Error for ticker BMC: Ticker BMC not found in SEC database
# Fetching CIK for S
# Fetching CIK for APOL
# Error for ticker APOL: Ticker APOL not found in SEC database
# Fetching CIK for FHN
# Fetching CIK for HNZ
# Error for ticker HNZ: Ticker HNZ not found in SEC database
# Fetching CIK for DF
# Error for ticker DF: Ticker DF not found in SEC database
# Fetching CIK for CVH
# Error for ticker CVH: Ticker CVH not found in SEC database
# Fetching CIK for PCS
# Error for ticker PCS: Ticker PCS not found in SEC database
# Fetching CIK for BIG
# Fetching CIK for FII
# Error for ticker FII: Ticker FII not found in SEC database

# %%
removed_tickers_df = removed_tickers_df.rename(columns = {'CIK':'removed_cik'})
removed_tickers_df
# Out:
#                Date_Removed           Security_Removed removed_cik
# Removed_Ticker
# RHI              2024-06-24                Robert Half  0000315213
# CMA              2024-06-24                   Comerica  0000028412
# ILMN             2024-06-24             Illumina, Inc.  0001110803
# PXD              2024-05-08  Pioneer Natural Resources         nan
# XRAY             2024-04-03            Dentsply Sirona  0000818479
# ...                     ...                        ...         ...
# DF               2013-05-23                 Dean Foods         nan
# CVH              2013-05-08       Coventry Health Care         nan
# PCS              2013-04-30                   MetroPCS         nan
# BIG              2013-02-15                   Big Lots  0000768835
# FII              2013-01-02        Federated Investors         nan
#
# [236 rows x 3 columns]

# %%
with open(data_folder_generate + 'sp500_df.pkl', 'rb') as f: 
    sp500_df = pickle.load(f)

# %%
sp500_df.head()
# Out:
#                    Security             GICS Sector  \
# Symbol
# MMM                      3M             Industrials
# AOS             A. O. Smith             Industrials
# ABT     Abbott Laboratories             Health Care
# ABBV                 AbbVie             Health Care
# ACN               Accenture  Information Technology
#
#                      GICS Sub-Industry  Date added         CIK      Founded
# Symbol
# MMM           Industrial Conglomerates  1957-03-04  0000066740         1902
# AOS                  Building Products  2017-07-26  0000091142         1916
# ABT              Health Care Equipment  1957-03-04  0000001800         1888
# ABBV                     Biotechnology  2012-12-31  0001551152  2013 (1888)
# ACN     IT Consulting & Other Services  2011-07-06  0001467373         1989

# %% [markdown]
# ## Step 3. Add the removed tickers to the sp500 tickers table

# %%
# merge the sp500_df with added_date
merged_df_added_date = pd.merge(left = sp500_df, right = added_tickers_df, left_index = True, right_index = True, how = 'outer')

#merge updated sp500_df with removed_date
merged_df_both_dates = pd.merge(left = merged_df_added_date, right = removed_tickers_df, left_index = True, right_index = True, how = 'outer')

merged_df_both_dates = merged_df_both_dates.reset_index()

merged_df_both_dates.rename(columns = {'Symbol':'Ticker'}, inplace = True)

merged_df_both_dates
# Out:
#     Ticker                 Security             GICS Sector  \
# 0        A     Agilent Technologies             Health Care
# 1       AA                      NaN                     NaN
# 2      AAL  American Airlines Group             Industrials
# 3      AAP                      NaN                     NaN
# 4     AAPL               Apple Inc.  Information Technology
# ..     ...                      ...                     ...
# 735    YUM              Yum! Brands  Consumer Discretionary
# 736    ZBH            Zimmer Biomet             Health Care
# 737   ZBRA       Zebra Technologies  Information Technology
# 738   ZION                      NaN                     NaN
# 739    ZTS                   Zoetis             Health Care
#
#                               GICS Sub-Industry  Date added         CIK  \
# 0                Life Sciences Tools & Services  2000-06-05  0001090872
# 1                                           NaN         NaN         NaN
# 2                            Passenger Airlines  2015-03-23  0000006201
# 3                                           NaN         NaN         NaN
# 4    Technology Hardware, Storage & Peripherals  1982-11-30  0000320193
# ..                                          ...         ...         ...
# 735                                 Restaurants  1997-10-06  0001041061
# 736                       Health Care Equipment  2001-08-07  0001136869
# 737          Electronic Equipment & Instruments  2019-12-23  0000877212
# 738                                         NaN         NaN         NaN
# 739                             Pharmaceuticals  2013-06-21  0001555280
#
#     Founded Date_Added           Security_Added Date_Removed  \
# 0      1999        NaT                      NaN          NaT
# 1       NaN        NaT                      NaN   2016-11-01
# 2      1934 2015-03-23  American Airlines Group          NaT
# 3       NaN 2015-07-08       Advance Auto Parts   2023-08-25
# 4      1977        NaT                      NaN          NaT
# ..      ...        ...                      ...          ...
# 735    1997        NaT                      NaN          NaT
# 736    1927        NaT                      NaN          NaT
# 737    1969 2019-12-23       Zebra Technologies          NaT
# 738     NaN        NaT                      NaN   2024-03-18
# 739    1952 2013-06-21                   Zoetis          NaT
#
#          Security_Removed removed_cik
# 0                     NaN         NaN
# 1                   Alcoa  0001675149
# 2                     NaN         NaN
# 3      Advance Auto Parts  0001158449
# 4                     NaN         NaN
# ..                    ...         ...
# 735                   NaN         NaN
# 736                   NaN         NaN
# 737                   NaN         NaN
# 738  Zions Bancorporation  0000109380
# 739                   NaN         NaN
#
# [740 rows x 12 columns]

# %% [markdown]
# ## Step 4. Clean up the merged sp500 tickers table

# %%
# Fill 'Security' with values from 'Security Added' and 'Security Removed'
merged_df_both_dates['Security'] = merged_df_both_dates['Security'].fillna(merged_df_both_dates['Security_Added']).fillna(merged_df_both_dates['Security_Removed'])

# Fill 'sp500cik' with values from 'removed_cik'
merged_df_both_dates['CIK'] = merged_df_both_dates['CIK'].fillna(merged_df_both_dates['removed_cik'])

# Fill 'Date added' with values from 'Date_Added'
merged_df_both_dates['Date added'] = merged_df_both_dates['Date added'].fillna(merged_df_both_dates['Date_Added'])

updated_merged_df_both_dates = merged_df_both_dates[~merged_df_both_dates['CIK'].isna()].copy()

updated_merged_df_both_dates = updated_merged_df_both_dates.drop(columns = ['Date_Added', 'Security_Added', 'Security_Removed', 'removed_cik'])

# filter out the tickers that don't have cik code on SEC.
updated_merged_df_both_dates_df = updated_merged_df_both_dates.loc[updated_merged_df_both_dates['CIK'] != "nan"].copy()

# Add the GICS sector label to the newly added tickers
updated_merged_df_both_dates_df['GICS Sector'].fillna(updated_merged_df_both_dates_df['Ticker'].map(removed_tickers_GICS_sector_category), inplace=True)

# %%
updated_merged_df_both_dates_df = updated_merged_df_both_dates_df.rename(columns = {'Date added':'Date_Added'})
new_column_order = ['Ticker', 'Security', 'GICS Sector', 'GICS Sub-Industry', 'Date_Added', 'Date_Removed', 'Founded', 'CIK']
reindexed_merged_sp500_df = updated_merged_df_both_dates_df[new_column_order].set_index('Ticker')
reindexed_merged_sp500_df
# Out:
#                        Security             GICS Sector  \
# Ticker
# A          Agilent Technologies             Health Care
# AA                        Alcoa               Materials
# AAL     American Airlines Group             Industrials
# AAP          Advance Auto Parts  Consumer Discretionary
# AAPL                 Apple Inc.  Information Technology
# ...                         ...                     ...
# YUM                 Yum! Brands  Consumer Discretionary
# ZBH               Zimmer Biomet             Health Care
# ZBRA         Zebra Technologies  Information Technology
# ZION       Zions Bancorporation              Financials
# ZTS                      Zoetis             Health Care
#
#                                  GICS Sub-Industry           Date_Added  \
# Ticker
# A                   Life Sciences Tools & Services           2000-06-05
# AA                                             NaN                  NaT
# AAL                             Passenger Airlines           2015-03-23
# AAP                                            NaN  2015-07-08 00:00:00
# AAPL    Technology Hardware, Storage & Peripherals           1982-11-30
# ...                                            ...                  ...
# YUM                                    Restaurants           1997-10-06
# ZBH                          Health Care Equipment           2001-08-07
# ZBRA            Electronic Equipment & Instruments           2019-12-23
# ZION                                           NaN                  NaT
# ZTS                                Pharmaceuticals           2013-06-21
#
#        Date_Removed Founded         CIK
# Ticker
# A               NaT    1999  0001090872
# AA       2016-11-01     NaN  0001675149
# AAL             NaT    1934  0000006201
# AAP      2023-08-25     NaN  0001158449
# AAPL            NaT    1977  0000320193
# ...             ...     ...         ...
# YUM             NaT    1997  0001041061
# ZBH             NaT    1927  0001136869
# ZBRA            NaT    1969  0000877212
# ZION     2024-03-18     NaN  0000109380
# ZTS             NaT    1952  0001555280
#
# [604 rows x 7 columns]

# %%
reindexed_merged_sp500_df = reindexed_merged_sp500_df.query('Security != "Under Armour"')

# %%
with open(data_folder_generate + 'sp500_df_v2.0.pkl', 'wb') as f:
    pickle.dump(reindexed_merged_sp500_df, f)

# %%
removed_tickers_GICS_sector_category = {
    'AA': 'Materials',
    'AAP': 'Consumer Discretionary',
    'ABMD': 'Health Care',
    'ACE': 'Financials',
    'ADS': 'Information Technology',
    'ADT': 'Industrials',
    'AET': 'Health Care',
    'AGN': 'Health Care',
    'AIV': 'Real Estate',
    'ALK': 'Industrials',
    'ALTR': 'Information Technology',
    'ALXN': 'Health Care',
    'AMG': 'Financials',
    'AN': 'Consumer Discretionary',
    'ANDV': 'Energy',
    'ANF': 'Consumer Discretionary',
    'APC': 'Energy',
    'APOL': 'Consumer Discretionary',
    'ARG': 'Materials',
    'ARNC': 'Materials',
    'ATI': 'Materials',
    'ATVI': 'Communication Services',
    'AVP': 'Consumer Staples',
    'AYI': 'Industrials',
    'BBBY': 'Consumer Discretionary',
    'BCR': 'Health Care',
    'BEAM': 'Health Care',
    'BHF': 'Financials',
    'BIG': 'Consumer Discretionary',
    'BMC': 'Information Technology',
    'BMS': 'Materials',
    'BRCM': 'Information Technology',
    'BTU': 'Energy',
    'BXLT': 'Health Care',
    'CA': 'Information Technology',
    'CAM': 'Energy',
    'CCE': 'Consumer Staples',
    'CDAY': 'Information Technology',
    'CELG': 'Health Care',
    'CERN': 'Health Care',
    'CFN': 'Health Care',
    'CHK': 'Energy',
    'CLF': 'Materials',
    'CMA': 'Financials',
    'CMCSK': 'Communication Services',
    'CNX': 'Energy',
    'COL': 'Industrials',
    'COTY': 'Consumer Staples',
    'COV': 'Health Care',
    'CPGX': 'Energy',
    'CPRI': 'Consumer Discretionary',
    'CSC': 'Information Technology',
    'CSRA': 'Information Technology',
    'CTXS': 'Information Technology',
    'CVC': 'Communication Services',
    'CVH': 'Health Care',
    'CXO': 'Energy',
    'DELL': 'Information Technology',
    'DF': 'Consumer Staples',
    'DISCK': 'Communication Services',
    'DISH': 'Communication Services',
    'DNB': 'Information Technology',
    'DNR': 'Energy',
    'DO': 'Energy',
    'DPS': 'Consumer Staples',
    'DRE': 'Real Estate',
    'DTV': 'Communication Services',
    'DWDP': 'Materials',
    'DXC': 'Information Technology',
    'EMC': 'Information Technology',
    'ENDP': 'Health Care',
    'ESRX': 'Health Care',
    'ESV': 'Energy',
    'ETFC': 'Financials',
    'EVHC': 'Health Care',
    'FB': 'Communication Services',
    'FBHS': 'Consumer Discretionary',
    'FDO': 'Consumer Discretionary',
    'FHN': 'Financials',
    'FII': 'Financials',
    'FL': 'Consumer Discretionary',
    'FLIR': 'Information Technology',
    'FLR': 'Industrials',
    'FLS': 'Industrials',
    'FLT': 'Information Technology',
    'FOSL': 'Consumer Discretionary',
    'FRC': 'Financials',
    'FRX': 'Health Care',
    'FTI': 'Energy',
    'FTR': 'Communication Services',
    'GAS': 'Utilities',
    'GGP': 'Real Estate',
    'GHC': 'Consumer Discretionary',
    'GMCR': 'Consumer Staples',
    'GME': 'Consumer Discretionary',
    'GNW': 'Financials',
    'GPS': 'Consumer Discretionary',
    'GT': 'Consumer Discretionary',
    'HAR': 'Consumer Discretionary',
    'HBI': 'Consumer Discretionary',
    'HCBK': 'Financials',
    'HFC': 'Energy',
    'HNZ': 'Consumer Staples',
    'HOG': 'Consumer Discretionary',
    'HOT': 'Consumer Discretionary',
    'HP': 'Energy',
    'HRB': 'Financials',
    'HSP': 'Health Care',
    'IGT': 'Consumer Discretionary',
    'ILMN': 'Health Care',
    'INFO': 'Information Technology',
    'IPGP': 'Information Technology',
    'JCP': 'Consumer Discretionary',
    'JDSU': 'Information Technology',
    'JEF': 'Financials',
    'JOY': 'Industrials',
    'JWN': 'Consumer Discretionary',
    'KORS': 'Consumer Discretionary',
    'KRFT': 'Consumer Staples',
    'KSS': 'Consumer Discretionary',
    'KSU': 'Industrials',
    'LEG': 'Consumer Discretionary',
    'LIFE': 'Health Care',
    'LLL': 'Industrials',
    'LLTC': 'Information Technology',
    'LM': 'Financials',
    'LNC': 'Financials',
    'LO': 'Consumer Staples',
    'LSI': 'Real Estate',
    'LUMN': 'Information Technology',
    'LVLT': 'Information Technology',
    'M': 'Consumer Discretionary',
    'MAC': 'Real Estate',
    'MAT': 'Consumer Discretionary',
    'MBC': 'Health Care',
    'MJN': 'Consumer Staples',
    'MNK': 'Health Care',
    'MOLX': 'Information Technology',
    'MON': 'Materials',
    'MUR': 'Energy',
    'MXIM': 'Information Technology',
    'NAVI': 'Financials',
    'NBL': 'Energy',
    'NBR': 'Energy',
    'NE': 'Energy',
    'NFX': 'Energy',
    'NKTR': 'Health Care',
    'NLSN': 'Communication Services',
    'NOV': 'Energy',
    'NWL': 'Consumer Discretionary',
    'NYX': 'Financials',
    'OGN': 'Health Care',
    'OI': 'Materials',
    'PBCT': 'Financials',
    'PBI': 'Industrials',
    'PCL': 'Real Estate',
    'PCP': 'Industrials',
    'PCS': 'Communication Services',
    'PDCO': 'Health Care',
    'PENN': 'Consumer Discretionary',
    'PETM': 'Consumer Discretionary',
    'PLL': 'Materials',
    'POM': 'Utilities',
    'PRGO': 'Health Care',
    'PVH': 'Consumer Discretionary',
    'PXD': 'Energy',
    'Q': 'Communication Services',
    'QEP': 'Energy',
    'R': 'Industrials',
    'RAI': 'Consumer Staples',
    'RDC': 'Energy',
    'RE': 'Financials',
    'RHI': 'Industrials',
    'RHT': 'Information Technology',
    'RIG': 'Energy',
    'RRC': 'Energy',
    'RTN': 'Industrials',
    'S': 'Communication Services',
    'SAI': 'Information Technology',
    'SBNY': 'Financials',
    'SCG': 'Utilities',
    'SE': 'Communication Services',
    'SEDG': 'Information Technology',
    'SEE': 'Materials',
    'SIAL': 'Materials',
    'SIG': 'Consumer Discretionary',
    'SIVB': 'Financials',
    'SLG': 'Real Estate',
    'SLM': 'Financials',
    'SNDK': 'Information Technology',
    'SNI': 'Communication Services',
    'SPLS': 'Consumer Discretionary',
    'SRCL': 'Industrials',
    'STI': 'Financials',
    'STJ': 'Health Care',
    'SWN': 'Energy',
    'SWY': 'Consumer Staples',
    'TDC': 'Information Technology',
    'TE': 'Utilities',
    'TEG': 'Utilities',
    'TGNA': 'Communication Services',
    'THC': 'Health Care',
    'TIF': 'Consumer Discretionary',
    'TRIP': 'Communication Services',
    'TSS': 'Information Technology',
    'TWC': 'Communication Services',
    'TWTR': 'Communication Services',
    'TWX': 'Communication Services',
    'TYC': 'Industrials',
    'UA': 'Consumer Discretionary',
    'UAA': 'Consumer Discretionary',
    'UNM': 'Financials',
    'URBN': 'Consumer Discretionary',
    'VAR': 'Health Care',
    'VFC': 'Consumer Discretionary',
    'VIAB': 'Communication Services',
    'VNO': 'Real Estate',
    'VNT': 'Industrials',
    'WCG': 'Health Care',
    'WFM': 'Consumer Staples',
    'WHR': 'Consumer Discretionary',
    'WIN': 'Communication Services',
    'WLTW': 'Financials',
    'WPX': 'Energy',
    'WU': 'Information Technology',
    'WYN': 'Consumer Discretionary',
    'X': 'Materials',
    'XEC': 'Energy',
    'XL': 'Financials',
    'XLNX': 'Information Technology',
    'XRAY': 'Health Care',
    'XRX': 'Information Technology',
    'YHOO': 'Communication Services',
    'ZION': 'Financials'
}
