# %% [markdown]
# # P1 - Download Financial Data for S&P500 Companies from SEC

# %% [markdown]
# ## Overview:
#
# This project aims to download financial data for S&P500 companies from SEC filings using the SEC API. The data gathered will be applied in the subsequent project to compute key financial metrics for factor-based investment analysis.
#
# Techniques used in the project:
#
# 1. Utilizing web scraping and API requests to collect company tickers and financial data. This includes interacting with the SEC database via submission and company fact APIs.
# 2. Processing JSON files and leveraging the requests library for API retrieval.
# 3. Manipulating time series data by resampling and aligning the datasets over uniform time periods.
# 4. Cleaning and adjusting the data, particularly dealing with cumulative figures and converting them into quarterly amounts for consistency.

# %%
# import libraries
import yfinance as yf
import pandas as pd
import requests
import json
import numpy as np
import pickle
import copy
import datetime as dt
import os

headers = {"User-Agent": "ian.ye.fu@gmail.com"} 

data_folder_download = './datasets/download/'
data_folder_generate = './datasets/generate/'

# %store -r removed_tickers_list

# %% [markdown]
# ## Step 1: Download S&P500 tickers from wikipedia

# %%
# Wikipedia URL for S&P 500
url = 'https://en.wikipedia.org/wiki/List_of_S%26P_500_companies'

# Read the HTML tables from the webpage
tables = pd.read_html(url)

# Table 1: List of S&P 500 companies
sp500_table = tables[0]

# Table 2: Recent changes to the S&P 500
recent_changes_table = tables[1]

# Save these tables to CSV files:
sp500_table.to_csv(data_folder_download + 'sp500_companies.csv', index=False)
recent_changes_table.to_csv(data_folder_download + 'sp500_recent_changes.csv', index=False)

# %%
# create a list of S&P500 tickers
sp500_df = pd.read_csv(data_folder_download + 'sp500_companies.csv', index_col = 0)
sp500_tickers = sp500_df.index.to_list()

# %%
# %store sp500_tickers
# Out:
# Stored 'sp500_tickers' (list)

# %%
sp500_df.head()
# Out:
#                    Security             GICS Sector  \
# Symbol
# MMM                      3M             Industrials
# AOS             A. O. Smith             Industrials
# ABT     Abbott Laboratories             Health Care
# ABBV                 AbbVie             Health Care
# ACN               Accenture  Information Technology
#
#                      GICS Sub-Industry    Headquarters Location  Date added  \
# Symbol
# MMM           Industrial Conglomerates    Saint Paul, Minnesota  1957-03-04
# AOS                  Building Products     Milwaukee, Wisconsin  2017-07-26
# ABT              Health Care Equipment  North Chicago, Illinois  1957-03-04
# ABBV                     Biotechnology  North Chicago, Illinois  2012-12-31
# ACN     IT Consulting & Other Services          Dublin, Ireland  2011-07-06
#
#             CIK      Founded
# Symbol
# MMM       66740         1902
# AOS       91142         1916
# ABT        1800         1888
# ABBV    1551152  2013 (1888)
# ACN     1467373         1989

# %% [markdown]
# ## Step 2: Convert the CIK code format to match SEC Fillings

# %%
# Create the CIK column and get sp500_cik_list
sp500_cik_list = [str(cik).zfill(10) for cik in sp500_df['CIK'].tolist()]  
sp500_cik = pd.Series(sp500_cik_list, index = sp500_df.index)
sp500_df['CIK'] = sp500_cik

# %%
sp500_df.drop(columns = 'Headquarters Location', inplace = True)

# %%
sp500_df.head()
# Out:
#                    Security             GICS Sector  \
# Symbol
# MMM                      3M             Industrials
# AOS             A. O. Smith             Industrials
# ABT     Abbott Laboratories             Health Care
# ABBV                 AbbVie             Health Care
# ACN               Accenture  Information Technology
#
#                      GICS Sub-Industry  Date added         CIK      Founded
# Symbol
# MMM           Industrial Conglomerates  1957-03-04  0000066740         1902
# AOS                  Building Products  2017-07-26  0000091142         1916
# ABT              Health Care Equipment  1957-03-04  0000001800         1888
# ABBV                     Biotechnology  2012-12-31  0001551152  2013 (1888)
# ACN     IT Consulting & Other Services  2011-07-06  0001467373         1989

# %%
sp500_df.loc['AAPL']
# Out:
# Security                                             Apple Inc.
# GICS Sector                              Information Technology
# GICS Sub-Industry    Technology Hardware, Storage & Peripherals
# Date added                                           1982-11-30
# CIK                                                  0000320193
# Founded                                                    1977
# Name: AAPL, dtype: object

# %%
with open(data_folder_generate + 'sp500_df_v1.0.pkl', 'wb') as f: 
    pickle.dump(sp500_df, f)

# %% [markdown]
# ## Step 4: Get all the company_fact data from downloaded archive json files.

# %%
def get_facts(ticker):
    """
    Load company_facts data from local json_file
    """
    cik = f'CIK{sp500_df.loc[ticker, 'CIK']}'
    directory = data_folder_download + 'companyfacts/'
    file_path = os.path.join(directory, f"{cik}.json")  # Example: specific file

    # Load the JSON data
    with open(file_path, 'r') as json_file:
        company_facts = json.load(json_file)

    # Print the keys in the root of the JSON to understand its structure
    return company_facts

# %%
# test get_facts function: success.
company_facts_appl = get_facts('AAPL')

# %% [markdown]
# ## Step 5: Create financials dataframes from the company_facts dict.

# %%
def facts_DF(ticker, headers=headers):
    """
    Convert the company_facts dict to dataframes
    """
    facts = get_facts(ticker)
    us_gaap_data = facts["facts"]["us-gaap"]
    df_data = []
    for fact, details in us_gaap_data.items():
        for unit in details["units"].keys():
            for item in details["units"][unit]:
                row = item.copy() # keep the original data intact
                row["fact"] = fact
                row['label'] = details['label']
                df_data.append(row)

    df = pd.DataFrame(df_data)
    df["end"] = pd.to_datetime(df["end"])
    df["start"] = pd.to_datetime(df["start"])
    df = df.drop_duplicates(subset=["fact", "end", "val"])
    df.set_index("end", inplace=True)
    labels_dict = {fact: details["label"] for fact, details in us_gaap_data.items()}
   
    return df

# %%
# test get_facts function: success.
ice_facts_df = facts_DF('ICE', headers)

# %% [markdown]
# ## Step 6: Define the financial data to be downloaded

# %%
pd.set_option('display.max_rows', None)

# %%
# get the data labels in the SEC database for all the essential financials for the factor calculation. 
data_category = ['Assets', 
                 'Liabilities', 
                 'LiabilitiesCurrent', 
                 'LiabilitiesNoncurrent', 
                 'LiabilitiesAndStockholdersEquity',  
                 'StockholdersEquity', 
                 'StockholdersEquityIncludingPortionAttributableToNoncontrollingInterest',
                 'EarningsPerShareDiluted', 
                 'CommonStockDividendsPerShareDeclared', 
                 'WeightedAverageNumberOfDilutedSharesOutstanding', 
                 'WeightedAverageNumberOfSharesOutstandingBasic',
                 'CommonStockSharesOutstanding',
                 'NetIncomeLoss' 
                 ]
# %store data_category
# Out:
# Stored 'data_category' (list)

# %% [markdown]
# ## Step 7: Download the financial data from SEC

# %%
def download_financial_data_from_SEC(sp500_tickers, data_category):
    """
    download all the financial metrics in the data_category from SEC for the sp500 companies 
    """
    sp500_financial_data = {} # outer dict
    
    for ticker in sp500_tickers:
        
        df = facts_DF(ticker)  # Correct data extraction for the ticker
        financial_data= {} # inner dict
        
        # Loop over all categories in the data_category list
        for category in data_category:
            
            x = df.query('fact == @category')
            # remove the duplicated rows based on 'end' index and keep the last record
            x = x[(x['val']!= 0) & (x['val'].notna())]
            cleaned_data = x[~x.index.duplicated(keep='last')].sort_index(ascending = True)
            # slice data from only 2013 onwards
            financial_data[category] = cleaned_data.loc['2013':]  
            
        # Assign the financial data for each ticker
        sp500_financial_data[ticker] = financial_data
        
    return  sp500_financial_data

# %%
sp500_financial_data = download_financial_data_from_SEC(sp500_tickers, data_category)

# %%
with open(data_folder_generate + 'sp500_financial_data_v1.0.pkl', 'wb') as f: 
    pickle.dump(sp500_financial_data, f)

# %% [markdown]
# ## Step 8: Clean the financial data from SEC

# %%
sp500_financial_data_updated = convert_annual_to_quarter(sp500_financial_data, updated_data_category)

# %%
# notice only I/S based metrics need to be updated.
updated_data_category = [
                 'EarningsPerShareDiluted',
                 'CommonStockDividendsPerShareDeclared', 
                 'NetIncomeLoss'
                 ]

def convert_annual_to_quarter(sp500_financial_data, updated_data_category):
    """
    This function updates financial data by subtracting the annual rows by 
    the sum of the previous three quarters for a given list of tickers and data categories
    """
    
    for ticker in sp500_financial_data.keys(): 

        for category in sp500_financial_data[ticker].keys(): 
            
            new_df = sp500_financial_data[ticker][category].reset_index().copy() 

            if category == "EarningsPerShareDiluted" or category == 'CommonStockDividendsPerShareDeclared' or category == 'NetIncomeLoss':

                # identify the annual rows
                index_list = new_df[(new_df['end'] - new_df['start']).dt.days > 130].index.tolist()
    
                # subtract the annual rows by the sum of the previous three quarters.
                for i in index_list: 
                    new_df.loc[i,'val'] = new_df.loc[i,'val'] - new_df.loc[i-3: i-1, 'val'].sum()
    
            sp500_financial_data[ticker][category] = new_df.set_index('end')
        
    return sp500_financial_data

# %%
sp500_financial_data_updated['ABNB']['StockholdersEquity']
# Out:
#                      val                  accn    fy  fp  form       filed  \
# end
# 2018-12-31 -5.173080e+08  0001559720-22-000006  2021  FY  10-K  2022-02-25
# 2019-12-31 -8.080000e+08  0001559720-23-000003  2022  FY  10-K  2023-02-17
# 2020-03-31 -1.117431e+09  0001628280-21-010389  2021  Q1  10-Q  2021-05-14
# 2020-06-30 -1.646645e+09  0001628280-21-016979  2021  Q2  10-Q  2021-08-13
# 2020-09-30 -1.376284e+09  0001559720-21-000017  2021  Q3  10-Q  2021-11-05
# 2020-12-31  2.901000e+09  0001559720-23-000003  2022  FY  10-K  2023-02-17
# 2021-03-31  3.159423e+09  0001628280-21-010389  2021  Q1  10-Q  2021-05-14
# 2021-06-30  3.393201e+09  0001628280-21-016979  2021  Q2  10-Q  2021-08-13
# 2021-09-30  4.448934e+09  0001559720-21-000017  2021  Q3  10-Q  2021-11-05
# 2021-12-31  4.775000e+09  0001559720-23-000003  2022  FY  10-K  2023-02-17
# 2022-03-31  4.737000e+09  0001559720-23-000010  2023  Q1  10-Q  2023-05-09
# 2022-06-30  5.245000e+09  0001559720-23-000015  2023  Q2  10-Q  2023-08-03
# 2022-09-30  5.540000e+09  0001559720-23-000020  2023  Q3  10-Q  2023-11-01
# 2022-12-31  5.560000e+09  0001559720-23-000003  2022  FY  10-K  2023-02-17
# 2023-03-31  5.291000e+09  0001559720-23-000010  2023  Q1  10-Q  2023-05-09
# 2023-06-30  5.059000e+09  0001559720-23-000015  2023  Q2  10-Q  2023-08-03
# 2023-09-30  9.123000e+09  0001559720-23-000020  2023  Q3  10-Q  2023-11-01
# 2023-12-31  8.165000e+09  0001559720-24-000006  2023  FY  10-K  2024-02-16
# 2024-03-31  7.896000e+09  0001559720-24-000017  2024  Q1  10-Q  2024-05-08
# 2024-06-30  8.002000e+09  0001559720-24-000024  2024  Q2  10-Q  2024-08-06
#
#                           fact                                        label  \
# end
# 2018-12-31  StockholdersEquity  Stockholders' Equity Attributable to Parent
# 2019-12-31  StockholdersEquity  Stockholders' Equity Attributable to Parent
# 2020-03-31  StockholdersEquity  Stockholders' Equity Attributable to Parent
# 2020-06-30  StockholdersEquity  Stockholders' Equity Attributable to Parent
# 2020-09-30  StockholdersEquity  Stockholders' Equity Attributable to Parent
# 2020-12-31  StockholdersEquity  Stockholders' Equity Attributable to Parent
# 2021-03-31  StockholdersEquity  Stockholders' Equity Attributable to Parent
# 2021-06-30  StockholdersEquity  Stockholders' Equity Attributable to Parent
# 2021-09-30  StockholdersEquity  Stockholders' Equity Attributable to Parent
# 2021-12-31  StockholdersEquity  Stockholders' Equity Attributable to Parent
# 2022-03-31  StockholdersEquity  Stockholders' Equity Attributable to Parent
# 2022-06-30  StockholdersEquity  Stockholders' Equity Attributable to Parent
# 2022-09-30  StockholdersEquity  Stockholders' Equity Attributable to Parent
# 2022-12-31  StockholdersEquity  Stockholders' Equity Attributable to Parent
# 2023-03-31  StockholdersEquity  Stockholders' Equity Attributable to Parent
# 2023-06-30  StockholdersEquity  Stockholders' Equity Attributable to Parent
# 2023-09-30  StockholdersEquity  Stockholders' Equity Attributable to Parent
# 2023-12-31  StockholdersEquity  Stockholders' Equity Attributable to Parent
# 2024-03-31  StockholdersEquity  Stockholders' Equity Attributable to Parent
# 2024-06-30  StockholdersEquity  Stockholders' Equity Attributable to Parent
#
#                 frame start
# end
# 2018-12-31  CY2018Q4I   NaT
# 2019-12-31  CY2019Q4I   NaT
# 2020-03-31        NaN   NaT
# 2020-06-30        NaN   NaT
# 2020-09-30  CY2020Q3I   NaT
# 2020-12-31        NaN   NaT
# 2021-03-31        NaN   NaT
# 2021-06-30        NaN   NaT
# 2021-09-30        NaN   NaT
# 2021-12-31        NaN   NaT
# 2022-03-31        NaN   NaT
# 2022-06-30        NaN   NaT
# 2022-09-30  CY2022Q3I   NaT
# 2022-12-31        NaN   NaT
# 2023-03-31        NaN   NaT
# 2023-06-30        NaN   NaT
# 2023-09-30  CY2023Q3I   NaT
# 2023-12-31        NaN   NaT
# 2024-03-31        NaN   NaT
# 2024-06-30  CY2024Q2I   NaT

# %%
with open(data_folder_generate +'sp500_financial_data_v1.1.pkl', 'wb') as f:
    pickle.dump(sp500_financial_data_updated, f)

# %% [markdown]
# ## Step 9: Download S&P500 stock daily price data from Yahoo Finance

# %%
syear = 2013
smonth = 1
sday = 1
eyear = 2024
emonth = 9
eday = 1

stocks_not_downloaded = []

folder = '../datasets/download/companyprice/'

interval = '1mo'
def save_to_csv_from_yahoo(folder, ticker, syear, smonth, sday, eyear, emonth, eday):
    """
    Download stock.['Adj Close'] data from Yahoo Finance and save them to folder.
    """
    start = dt.datetime(syear, smonth, sday)
    end = dt.datetime(eyear, emonth, eday)
    print('Get Data for:', ticker)
    df = yf.download(ticker, start, end)['Adj Close']
    
    if df.empty:
        print("Couldn't Get Data for: ", ticker)
        stocks_not_downloaded.append(ticker)
    df.to_csv(folder + ticker + '.csv')

# %%
# convert the '.' ticker format to '-' ticker format.
tickers_not_downloaded = [ticker.replace('.', '-') for ticker in stocks_not_downloaded]

# %%
for ticker in sp500_df.index.to_list(): 
    save_to_csv_from_yahoo(folder, ticker, syear, smonth, sday, eyear, emonth, eday)

# %%
# redownloaded the failed tickers 
for ticker in tickers_not_downloaded: 
    save_to_csv_from_yahoo(folder, ticker, syear, smonth, sday, eyear, emonth, eday, interval)
# Out:
# Get Data for: BRK-B
# [*********************100%%**********************]  1 of 1 completed
# Get Data for: BF-B
# [*********************100%%**********************]  1 of 1 completed

# %%
for ticker in removed_tickers_list: 
    save_to_csv_from_yahoo(folder, ticker, syear, smonth, sday, eyear, emonth, eday)
# Out:
# Get Data for: AA
# [*********************100%%**********************]  1 of 1 completed
# Get Data for: AAP
# [*********************100%%**********************]  1 of 1 completed
# Get Data for: ADT
# [*********************100%%**********************]  1 of 1 completed
# Get Data for: AIV
# [*********************100%%**********************]  1 of 1 completed
# Get Data for: ALK
# [*********************100%%**********************]  1 of 1 completed
# Get Data for: ALTR
# [*********************100%%**********************]  1 of 1 completed
# Get Data for: AMG
# [*********************100%%**********************]  1 of 1 completed
# Get Data for: AN
# [*********************100%%**********************]  1 of 1 completed
# Get Data for: ANF
# [*********************100%%**********************]  1 of 1 completed
# Get Data for: ATI
# [*********************100%%**********************]  1 of 1 completed
# Get Data for: AYI
# [*********************100%%**********************]  1 of 1 completed
# Get Data for: BEAM
# [*********************100%%**********************]  1 of 1 completed
# Get Data for: BHF
# [*********************100%%**********************]  1 of 1 completed
# Get Data for: BIG
# [*********************100%%**********************]  1 of 1 completed
# Get Data for: BTU
# [*********************100%%**********************]  1 of 1 completed
# Get Data for: CHK
# [*********************100%%**********************]  1 of 1 completed
# Get Data for: CLF
# [*********************100%%**********************]  1 of 1 completed
# Get Data for: CMA
# [*********************100%%**********************]  1 of 1 completed
# Get Data for: CNX
# [*********************100%%**********************]  1 of 1 completed
# Get Data for: COTY
# [*********************100%%**********************]  1 of 1 completed
# Get Data for: CPRI
# [*********************100%%**********************]  1 of 1 completed
# Get Data for: DELL
# [*********************100%%**********************]  1 of 1 completed
# Get Data for: DNB
# [*********************100%%**********************]  1 of 1 completed
# Get Data for: DO
# [*********************100%%**********************]  1 of 1 completed
# Get Data for: DXC
# [*********************100%%**********************]  1 of 1 completed
# Get Data for: FHN
# [*********************100%%**********************]  1 of 1 completed
# Get Data for: FL
# [*********************100%%**********************]  1 of 1 completed
# Get Data for: FLR
# [*********************100%%**********************]  1 of 1 completed
# Get Data for: FLS
# [*********************100%%**********************]  1 of 1 completed
# Get Data for: FOSL
# [*********************100%%**********************]  1 of 1 completed
# Get Data for: FTI
# [*********************100%%**********************]  1 of 1 completed
# Get Data for: GHC
# [*********************100%%**********************]  1 of 1 completed
# Get Data for: GME
# [*********************100%%**********************]  1 of 1 completed
# Get Data for: GNW
# [*********************100%%**********************]  1 of 1 completed
# Get Data for: GPS
# [*********************100%%**********************]  1 of 1 completed
# Get Data for: GT
# [*********************100%%**********************]  1 of 1 completed
# Get Data for: HBI
# [*********************100%%**********************]  1 of 1 completed
# Get Data for: HOG
# [*********************100%%**********************]  1 of 1 completed
# Get Data for: HP
# [*********************100%%**********************]  1 of 1 completed
# Get Data for: HRB
# [*********************100%%**********************]  1 of 1 completed
# Get Data for: IGT
# [*********************100%%**********************]  1 of 1 completed
# Get Data for: ILMN
# [*********************100%%**********************]  1 of 1 completed
# Get Data for: IPGP
# [*********************100%%**********************]  1 of 1 completed
# Get Data for: JEF
# [*********************100%%**********************]  1 of 1 completed
# Get Data for: JWN
# [*********************100%%**********************]  1 of 1 completed
# Get Data for: KSS
# [*********************100%%**********************]  1 of 1 completed
# Get Data for: LEG
# [*********************100%%**********************]  1 of 1 completed
# Get Data for: LNC
# [*********************100%%**********************]  1 of 1 completed
# Get Data for: LUMN
# [*********************100%%**********************]  1 of 1 completed
# Get Data for: M
# [*********************100%%**********************]  1 of 1 completed
# Get Data for: MAC
# [*********************100%%**********************]  1 of 1 completed
# Get Data for: MAT
# [*********************100%%**********************]  1 of 1 completed
# Get Data for: MBC
# [*********************100%%**********************]  1 of 1 completed
# Get Data for: MUR
# [*********************100%%**********************]  1 of 1 completed
# Get Data for: NAVI
# [*********************100%%**********************]  1 of 1 completed
# Get Data for: NBR
# [*********************100%%**********************]  1 of 1 completed
# Get Data for: NE
# [*********************100%%**********************]  1 of 1 completed
# Get Data for: NKTR
# [*********************100%%**********************]  1 of 1 completed
# Get Data for: NOV
# [*********************100%%**********************]  1 of 1 completed
# Get Data for: NWL
# [*********************100%%**********************]  1 of 1 completed
# Get Data for: OGN
# [*********************100%%**********************]  1 of 1 completed
# Get Data for: OI
# [*********************100%%**********************]  1 of 1 completed
# Get Data for: PBI
# [*********************100%%**********************]  1 of 1 completed
# Get Data for: PDCO
# [*********************100%%**********************]  1 of 1 completed
# Get Data for: PENN
# [*********************100%%**********************]  1 of 1 completed
# Get Data for: PLL
# [*********************100%%**********************]  1 of 1 completed
# Get Data for: PRGO
# [*********************100%%**********************]  1 of 1 completed
# Get Data for: PVH
# [*********************100%%**********************]  1 of 1 completed
# Get Data for: R
# [*********************100%%**********************]  1 of 1 completed
# Get Data for: RHI
# [*********************100%%**********************]  1 of 1 completed
# Get Data for: RIG
# [*********************100%%**********************]  1 of 1 completed
# Get Data for: RRC
# [*********************100%%**********************]  1 of 1 completed
# Get Data for: S
# [*********************100%%**********************]  1 of 1 completed
# Get Data for: SAI
# [*********************100%%**********************]  1 of 1 completed
# Get Data for: SE
# [*********************100%%**********************]  1 of 1 completed
# Get Data for: SEDG
# [*********************100%%**********************]  1 of 1 completed
# Get Data for: SEE
# [*********************100%%**********************]  1 of 1 completed
# Get Data for: SIG
# [*********************100%%**********************]  1 of 1 completed
# Get Data for: SLG
# [*********************100%%**********************]  1 of 1 completed
# Get Data for: SLM
# [*********************100%%**********************]  1 of 1 completed
# Get Data for: SRCL
# [*********************100%%**********************]  1 of 1 completed
# Get Data for: STI
# [*********************100%%**********************]  1 of 1 completed
# Get Data for: SWN
# [*********************100%%**********************]  1 of 1 completed
# Get Data for: TDC
# [*********************100%%**********************]  1 of 1 completed
# Get Data for: TGNA
# [*********************100%%**********************]  1 of 1 completed
# Get Data for: THC
# [*********************100%%**********************]  1 of 1 completed
# Get Data for: TRIP
# [*********************100%%**********************]  1 of 1 completed
# Get Data for: UA
# [*********************100%%**********************]  1 of 1 completed
# Get Data for: UAA
# [*********************100%%**********************]  1 of 1 completed
# Get Data for: UNM
# [*********************100%%**********************]  1 of 1 completed
# Get Data for: URBN
# [*********************100%%**********************]  1 of 1 completed
# Get Data for: VFC
# [*********************100%%**********************]  1 of 1 completed
# Get Data for: VNO
# [*********************100%%**********************]  1 of 1 completed
# Get Data for: VNT
# [*********************100%%**********************]  1 of 1 completed
# Get Data for: WHR
# [*********************100%%**********************]  1 of 1 completed
# Get Data for: WU
# [*********************100%%**********************]  1 of 1 completed
# Get Data for: X
# [*********************100%%**********************]  1 of 1 completed
# Get Data for: XRAY
# [*********************100%%**********************]  1 of 1 completed
# Get Data for: XRX
# [*********************100%%**********************]  1 of 1 completed
# Get Data for: ZION
# [*********************100%%**********************]  1 of 1 completed

# %%
# download cap-weighted sp500 index historical performance. 
save_to_csv_from_yahoo('./', '^GSPC', syear, smonth, sday, eyear, emonth, eday)
# Out:
# Get Data for: ^GSPC
# [*********************100%%**********************]  1 of 1 completed

# %%
# download equal-weighted sp500 index historical performance. 
save_to_csv_from_yahoo('./', '^SPXEW', syear, smonth, sday, eyear, emonth, eday)
# Out:
# Get Data for: ^SPXEW
# [*********************100%%**********************]  1 of 1 completed
